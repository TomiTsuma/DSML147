# %%
# !pip install psycopg2 sqlalchemy 
# !pip install mariadb
# !pip install dask
# !pip install dask[dataframe]

# %%
import psycopg2
import sqlalchemy as sq
import pandas as pd
import numpy as np
import mariadb
import dask.dataframe as dd
import json
import os
import shutil
import subprocess
from pathlib import Path

# %%
import mariadb
import sys

username = "scoring"
password = "idkltb93e0eomejp"
host = 'spectral-msql-jul-24-backup-do-user-2276924-0.b.db.ondigitalocean.com'
port = 25060
database="farmlabv3_live"
# schema="farmlabv3_live"
# schema="historical"
def get_db_cursor():
    try:
        conn = mariadb.connect(
            user=username,
            password=password,
            host=host,
            port=port,
            database=database
    
        )
        return conn
    except mariadb.Error as e:
        print(f"Error connecting to MariaDB Platform: {e}")
        sys.exit(1)

conn = get_db_cursor()
cur = conn.cursor()

# %%
report_data = pd.read_sql("SELECT spectral_sample_id, barcode, crop_id, report_data  FROM SpectralSampleCrop ssc", con=conn)
# Out:
# C:\Users\tommy\AppData\Local\Temp\ipykernel_23900\2048603924.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   report_data = pd.read_sql("SELECT spectral_sample_id, barcode, crop_id, report_data  FROM SpectralSampleCrop ssc", con=conn)

# %%
crops = pd.read_sql("SELECT id, name FROM crop c", con=conn, index_col="name").to_dict()
# Out:
# C:\Users\tommy\AppData\Local\Temp\ipykernel_27780\1915557479.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crops = pd.read_sql("SELECT id, name FROM crop c", con=conn, index_col="name").to_dict()

# %%
crops
# Out:
# {'id': {'Maize': 199,
#   'sorghum': 144,
#   'Soya bean (opv)': 3,
#   'millet': 4,
#   'coffee': 5,
#   'rice': 6,
#   'Maize_irrigated': 7,
#   'Maize_rainfed': 8,
#   'Peanuts': 9,
#   'Potatoes (Irish)': 40,
#   'Onions': 11,
#   'Tomatoes_op': 12,
#   'Tomatoes_hybrid': 13,
#   'Orange Flesh Sweet Potato': 14,
#   'Beans': 145,
#   'Groundnuts': 16,
#   'Orange Flesh Sweet Potat': 17,
#   'Tobacco': 18,
#   'Cabbage': 19,
#   'maize': 20,
#   'Maize (hybrid)': 21,
#   'Carrots': 22,
#   'Rhodesian blue grass': 24,
#   'Napier grass': 25,
#   'Maize (OPV)': 205,
#   'Sunflower': 27,
#   'Irish_Potatoes': 28,
#   'Yam': 29,
#   'Cassava': 30,
#   'Yams': 31,
#   'Cotton': 32,
#   'Napier Grass': 33,
#   'Chloris gayanas (Rhodes grass)': 36,
#   'Gamba grass(Andropogon gayanas)': 35,
#   'Fallow': 37,
#   'pyrethrum': 38,
#   'Maize (Seed)': 39,
#   'Potato': 41,
#   'Onion (Spring)': 42,
#   'Maize Grain': 43,
#   'French Bean Trash': 44,
#   'Grass (Grazing)': 45,
#   'Tomatoes (OP)': 46,
#   'Tomatoes (Hybrid)': 47,
#   'Tea': 48,
#   'Snow peas': 49,
#   'Peas': 50,
#   'Onion (Bulb)': 51,
#   'Onions (Spring)': 52,
#   'Bean (French) Pods': 54,
#   'Potato Tubers': 55,
#   'Irish Potatoes (Hybrid)': 57,
#   'Cow Pea Grains': 58,
#   'Sugar Snap': 59,
#   'Beans (French)': 63,
#   'Mange Tout': 61,
#   'Garden Pea': 62,
#   'Fine beans': 64,
#   'Maize (Dryland)': 65,
#   'Tomatoes (Open field)': 66,
#   'Beans (Fine)': 67,
#   'Green Grams': 68,
#   'Cow peas': 148,
#   'Sesame': 70,
#   'Carrot': 71,
#   'Kale': 72,
#   'Spinach': 73,
#   'No Crop': 75,
#   'Amaranth (Grain)': 76,
#   'Beans (Yellow)': 77,
#   'Beans (Nyayo)': 78,
#   'Wheat': 80,
#   'Beans (faba)': 81,
#   'Finger millet': 82,
#   'Sweet Potato': 83,
#   'Garlic': 84,
#   'Passion Fruit': 85,
#   'Black Night Shade': 86,
#   'Pumpkin': 87,
#   'Crotalaria': 88,
#   'Spider Plant': 98,
#   'Jute Mallow': 90,
#   'African Kale': 91,
#   'Macadamia': 92,
#   'Avocado': 93,
#   'Banana': 94,
#   'Sugar Cane': 95,
#   'Ground Nut': 96,
#   'None': 99,
#   'Mango': 100,
#   'Lucerne': 101,
#   'Water Melon': 102,
#   'Oranges': 103,
#   'Baby Corns': 104,
#   'Lettuce': 105,
#   'Bell Pepper': 106,
#   'Habanero': 107,
#   'Cucumber': 108,
#   'Tomatoes': 109,
#   'Watermelon': 110,
#   'Capsicum': 111,
#   'capcicum': 112,
#   'Chilli': 113,
#   'Pigeon pea': 114,
#   'Pigeon Peas': 147,
#   'Mustard': 116,
#   'Oats': 117,
#   'Vetch': 118,
#   'Tree tomato': 121,
#   'Maize (Irrigated)': 122,
#   'Maize (Rain-fed)': 123,
#   'Avocado (Hass, Irrigated)': 124,
#   'Miraa(Khat)': 125,
#   'Cowpea': 126,
#   'Cowpeas': 127,
#   'Cashewnuts': 128,
#   'Okra': 129,
#   'Palm (Hybrid)': 131,
#   'cashew nuts': 134,
#   'Palm oil': 135,
#   'Chloris (Hay)': 136,
#   'Sudan grass.': 137,
#   'Oil Palm (OPV)': 138,
#   'Maize (Silage)': 139,
#   'Sorghum (Silage)': 140,
#   'Bananas': 141,
#   'Bean (Nyota)': 142,
#   'Maize hybrid': 143,
#   'green grams': 146,
#   '35.02070': 149,
#   '35.03062': 150,
#   '35.02986': 151,
#   '35.02866': 152,
#   '35.02472': 153,
#   '35.02541': 154,
#   '35.01889': 155,
#   '35.02451': 156,
#   'Groundnut': 157,
#   'Ginger': 158,
#   '35.07378': 159,
#   'Cocoa': 160,
#   'Soyabeans': 161,
#   'Canola (OSR)': 162,
#   'Vegetables (General)': 163,
#   'Beans6:Millet': 164,
#   'Beans12:Sweet Potato': 165,
#   'Vegetables (General)7:Spinach': 166,
#   'Soy': 174,
#   'Tomatoes (OPV)': 175,
#   'Irish Potatoes (OPV)': 177,
#   'Rice (Hybrid)': 178,
#   'Rice (OPV)': 179,
#   'Sorghum (Hybrid)': 180,
#   'Sorghum (OPV)': 181,
#   'Cocoa (OPV)': 182,
#   'Kales': 184,
#   'Nappeir grass': 185,
#   'Soya bean (Hybrid)': 189,
#   'Sweet potatoes': 190,
#   'Maize opv': 192,
#   'Maize Hybrid': 193,
#   'Soya Beans': 195,
#   'Maize (Hybrid)': 197,
#   'Passion Fruits': 198,
#   'Barley': 201,
#   'Soya': 202,
#   'Pyrethum': 203,
#   'Soya bean (OPV)': 206,
#   'Groundnut (Hybrid)': 207,
#   'Cotton (opv)': 208,
#   'Cassava (Hybrid)': 209,
#   'Onions (bulb)': 212,
#   'Sesame (Simsim)': 213,
#   'Wheat (OPV)': 214,
#   'Potatoes (Irish) OPV': 216,
#   '': 218,
#   'Potatoes (Irish0 Hybrid': 219,
#   'Potatoes (Irish) Hybrid': 220,
#   'Irish potatoes  (OPV)': 221,
#   'Maize New': 222,
#   'Mazie': 223,
#   'Cassava (OPV)': 224,
#   'Irish Potatoes': 225,
#   'Groundnut (OPV)': 226,
#   'Bananas (opv)': 227,
#   'Bananas (Hybrid)': 228,
#   'Strawberry': 229,
#   'Rhodes Grass': 230,
#   'Sudan grass': 231,
#   'Amaranth': 232,
#   'Sugarcane (planting)': 233,
#   'No': 234,
#   'Green Gram': 235,
#   'Potato (Irish)': 236,
#   'Oil Palm': 237,
#   'Pineapple': 240,
#   'Wheat (hybrid)': 241,
#   'Groundnut (hybrid)': 242,
#   'Rice(OPV)': 243,
#   'Groundnuts (OPV)': 244,
#   'rice opv': 245,
#   'Rice hybrid': 246,
#   'Citrus': 247,
#   'brocholli': 248,
#   'cabbages': 249,
#   'Grass': 250,
#   'Grass (Kikuyu)': 251,
#   'potatoes': 252,
#   'carrots beans maize': 253,
#   'cabbage maize onions': 254,
#   'cabbage maize': 255,
#   'maize potatoes': 256,
#   'Kikuyu Grass': 257}}

# %%
report_data = pd.read_csv("inputFiles/report_data.csv")

# %%
report_data
# Out:
#         Unnamed: 0  spectral_sample_id         barcode  crop_id  \
# 0                0              110990  AGR-FL-1684-38       38
# 1                1              110990   AGR-FL-1684-1        1
# 2                2              110990  AGR-FL-1684-10       10
# 3                3              110994  AGR-FL-1671-38       38
# 4                4              110994   AGR-FL-1671-1        1
# ...            ...                 ...             ...      ...
# 202963      202963              248768  RWA-TS-3937-21       21
# 202964      202964              248771  RWA-TS-3936-21       21
# 202965      202965              206249   PAG-FL-1884-1        1
# 202966      202966              149485  PAG-FL-0002-10       10
# 202967      202967              149485  PAG-FL-0002-15       15
#
#                                               report_data
# 0       b'{"AGR-FL-1684-38": {"results": [{"result": "...
# 1       b'{"AGR-FL-1684-1": {"results": [{"result": "6...
# 2       b'{"AGR-FL-1684-10": {"results": [{"result": "...
# 3       b'{"AGR-FL-1671-38": {"results": [{"result": "...
# 4       b'{"AGR-FL-1671-1": {"results": [{"result": "6...
# ...                                                   ...
# 202963  b'{"RWA-TS-3937-21": {"results": [{"result": "...
# 202964  b'{"RWA-TS-3936-21": {"results": [{"result": "...
# 202965  b'{"PAG-FL-1884-1": {"results": [{"result": "5...
# 202966  b'{"PAG-FL-0002-10": {"results": [{"result": "...
# 202967  b'{"PAG-FL-0002-15": {"results": [{"result": "...
#
# [202968 rows x 5 columns]

# %%
report_data.to_csv("inputFiles/report_data.csv")

# %%
comparison_df = pd.read_csv("inputFiles/approval-check.csv")

# %%
reports = pd.DataFrame()

# %%
ct = 0
name = []
client = []
lat= []
lng = []
crop = []
for i in report_data['report_data']:
    ct+=1
    print(ct)
    # try:
    res = json.loads(eval(i))
    index = [j for j in res.keys()][0]
    print(index)
    farmer_dets = (res[index]['farmer_details'])
    name.append(farmer_dets['farmer_name'])
    client.append(farmer_dets['client_name'])
    lat.append(farmer_dets['lat'])
    lng.append(farmer_dets['lng'])
    crop.append(farmer_dets['crop'])
                
    continue
        
#         results = res[index]['results']
#         _df = pd.DataFrame(results)
#         _df['barcode'] = "-".join(index.split("-")[:-1])
#         _df['crop_code'] = index.split("-")[-1]
#         reports = pd.concat([reports, _df])
        
        
#     except Exception as e:
#         print(e)
# # reports.to_csv("inputFiles/reports_cleaned.csv")
# Out:
# 1
# AGR-FL-1684-38
# 2
# AGR-FL-1684-1
# 3
# AGR-FL-1684-10
# 4
# AGR-FL-1671-38
# 5
# AGR-FL-1671-1
# 6
# AGR-FL-1671-10
# 7
# AGR-FL-1501-38
# 8
# AGR-FL-1501-1
# 9
# AGR-FL-1501-10
# 10
# AGR-FL-1503-38
# 11
# AGR-FL-1503-1
# 12
# AGR-FL-1503-10
# 13
# AGR-FL-1504-38
# 14
# AGR-FL-1504-1
# 15
# AGR-FL-1504-10
# 16
# AGR-FL-1505-38
# 17
# AGR-FL-1505-1
# 18
# AGR-FL-1505-10
# 19
# AGR-FL-1506-38
# 20
# AGR-FL-1506-1
# 21
# AGR-FL-1506-10
# 22
# AGR-FL-1507-38
# 23
# AGR-FL-1507-1
# 24
# AGR-FL-1507-10
# 25
# AGR-FL-1509-38
# 26
# AGR-FL-1509-1
# 27
# AGR-FL-1509-10
# 28
# AGR-FL-1511-38
# 29
# AGR-FL-1511-1
# 30
# AGR-FL-1511-10
# 31
# AGR-FL-1523-38
# 32
# AGR-FL-1523-1
# 33
# AGR-FL-1523-10
# 34
# AGR-FL-1517-38
# 35
# AGR-FL-1517-1
# 36
# AGR-FL-1517-10
# 37
# AGR-FL-1528-38
# 38
# AGR-FL-1528-1
# 39
# AGR-FL-1528-10
# 40
# AGR-FL-1514-38
# 41
# AGR-FL-1514-1
# 42
# AGR-FL-1514-10
# 43
# AGR-FL-1520-38
# 44
# AGR-FL-1520-1
# 45
# AGR-FL-1520-10
# 46
# AGR-FL-1532-38
# 47
# AGR-FL-1532-1
# 48
# AGR-FL-1532-10
# 49
# AGR-FL-1535-38
# 50
# AGR-FL-1535-1
# 51
# AGR-FL-1535-10
# 52
# AGR-FL-1536-38
# 53
# AGR-FL-1536-1
# 54
# AGR-FL-1536-10
# 55
# AGR-FL-1537-38
# 56
# AGR-FL-1537-1
# 57
# AGR-FL-1537-10
# 58
# AGR-FL-1538-38
# 59
# AGR-FL-1538-1
# 60
# AGR-FL-1538-10
# 61
# AGR-FL-1266-38
# 62
# AGR-FL-1266-1
# 63
# AGR-FL-1266-10
# 64
# AGR-FL-1262-38
# 65
# AGR-FL-1262-1
# 66
# AGR-FL-1262-10
# 67
# AGR-FL-0088-38
# 68
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 11
#       9 print(ct)
#      10 # try:
# ---> 11 res = json.loads(eval(i))
#      12 index = [j for j in res.keys()][0]
#      13 print(index)
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
reports = pd.read_csv("inputFiles/reports_cleaned.csv")
# Out:
# C:\Users\tommy\AppData\Local\Temp\ipykernel_16880\4068765364.py:1: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports = pd.read_csv("inputFiles/reports_cleaned.csv")

# %%
reports_pivot = reports.copy(deep=True)

# %%
reports_pivot["barcode_crop"] = reports_pivot['barcode'] + "_" + reports_pivot['crop_code'].astype("str")

# %%
reports_pivot
# Out:
#          Unnamed: 0 result     status result_unit   chemical_name  \
# 0                 0   6.00        Low           %              ph
# 1                 1  10-30        Low         ppm     available p
# 2                 2    632  Very High         ppm  exchangeable k
# 3                 3   1610    Optimum         ppm         calcium
# 4                 4    294    Optimum         ppm       magnesium
# ...             ...    ...        ...         ...             ...
# 2531601          13   15.5    Optimum         NaN       c/n ratio
# 2531602          14     66       High           %            clay
# 2531603          15   14.7        Low           %            silt
# 2531604          16   19.3        Low           %            sand
# 2531605          17  HClay        NaN         NaN    soil texture
#
#               barcode crop_code    0      barcode_crop
# 0         AGR-FL-1684        38  NaN    AGR-FL-1684_38
# 1         AGR-FL-1684        38  NaN    AGR-FL-1684_38
# 2         AGR-FL-1684        38  NaN    AGR-FL-1684_38
# 3         AGR-FL-1684        38  NaN    AGR-FL-1684_38
# 4         AGR-FL-1684        38  NaN    AGR-FL-1684_38
# ...               ...       ...  ...               ...
# 2531601  OCP-PL-00140       180  NaN  OCP-PL-00140_180
# 2531602  OCP-PL-00140       180  NaN  OCP-PL-00140_180
# 2531603  OCP-PL-00140       180  NaN  OCP-PL-00140_180
# 2531604  OCP-PL-00140       180  NaN  OCP-PL-00140_180
# 2531605  OCP-PL-00140       180  NaN  OCP-PL-00140_180
#
# [2531606 rows x 9 columns]

# %%
reports_pivot['chemical_name'] = reports_pivot['chemical_name'].str.lower().replace("/","").replace(" ","_").replace(".","")

# %%
reports_pivot['chemical_name'] = [str(i).replace("/","").replace(" ","_").replace(".","") for i in reports_pivot['chemical_name']]

# %%
reports_pivot = reports_pivot.reset_index()

# %%
reports_pivot = reports_pivot.dropna(subset="status")

# %%
reports_pivot['status'] = reports_pivot['status'].str.lower()

# %%
reports_pivot['status'] = [i.strip() for i in reports_pivot['status']]

# %%
reports_pivot.loc[reports_pivot['barcode'] == "1692083006981"]
# Out:
#            index  Unnamed: 0 result     status result_unit   chemical_name  \
# 2360831  2360831           0   2.00   very low         NaN              ph
# 2360832  2360832           1   < 10   very low         ppm     available_p
# 2360833  2360833           2   < 40   very low         ppm  exchangeable_k
# 2360836  2360836           5     60    optimum         ppm            iron
# 2360837  2360837           6     60    optimum         ppm       manganese
# 2360838  2360838           7     60  very high         ppm           boron
# 2360839  2360839           8     60  very high         ppm          copper
# 2360840  2360840           9     60  very high         ppm            zinc
# 2360841  2360841          10  -37.3   very low    meq/100g             cec
# 2360842  2360842          11      3  very high           %  total_nitrogen
# 2360843  2360843          12   5.16    optimum           %  organic_matter
# 2360844  2360844          13      1   very low         NaN        cn_ratio
# 2360845  2360845          14      0   very low           %            clay
# 2360846  2360846          15      0   very low           %            silt
#
#                barcode crop_code    0      barcode_crop
# 2360831  1692083006981        10  NaN  1692083006981_10
# 2360832  1692083006981        10  NaN  1692083006981_10
# 2360833  1692083006981        10  NaN  1692083006981_10
# 2360836  1692083006981        10  NaN  1692083006981_10
# 2360837  1692083006981        10  NaN  1692083006981_10
# 2360838  1692083006981        10  NaN  1692083006981_10
# 2360839  1692083006981        10  NaN  1692083006981_10
# 2360840  1692083006981        10  NaN  1692083006981_10
# 2360841  1692083006981        10  NaN  1692083006981_10
# 2360842  1692083006981        10  NaN  1692083006981_10
# 2360843  1692083006981        10  NaN  1692083006981_10
# 2360844  1692083006981        10  NaN  1692083006981_10
# 2360845  1692083006981        10  NaN  1692083006981_10
# 2360846  1692083006981        10  NaN  1692083006981_10

# %%
reports_pivot['status'].value_counts()
# Out:
# status
# optimum      1108016
# very low      408372
# low           383478
# very high     258147
# high          111678
# Name: count, dtype: int64

# %%
status_dict ={
    "very low":0,
    "low":1,
    "optimum":2,
    "high":3,
    "very high":3
}

status_dict_inv ={
    0: "very low",
    1: "low",
    2: "optimum",
    3: "high",
}

# %%
reports_pivot['status'] = [status_dict[i] for i in reports_pivot['status']]

# %%
reports_pivot.status.value_counts()
# Out:
# status
# 2    1108016
# 0     408372
# 1     383478
# 3     369825
# Name: count, dtype: int64

# %%
reports_pivot_2 = pd.pivot_table(data=reports_pivot,index="barcode_crop",columns="chemical_name",values="status", aggfunc=max)
# Out:
# C:\Users\tommy\AppData\Local\Temp\ipykernel_16880\902337865.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   reports_pivot_2 = pd.pivot_table(data=reports_pivot,index="barcode_crop",columns="chemical_name",values="status", aggfunc=max)

# %%
reports_pivot_2
# Out:
# chemical_name     available_p  boron  calcium  cec  clay  cn_ratio  copper  \
# barcode_crop
# 0.P-GB_8669               0.0    1.0      2.0  0.0   1.0       NaN     1.0
# 0CP-AE_.3448              0.0    0.0      2.0  1.0   3.0       2.0     2.0
# 1692083006981_10          0.0    3.0      NaN  0.0   0.0       0.0     3.0
# 1693472359551_10          1.0    3.0      NaN  2.0   0.0       2.0     3.0
# 1693917106291_10          1.0    3.0      NaN  2.0   0.0       2.0     3.0
# ...                       ...    ...      ...  ...   ...       ...     ...
# stk-fl-4293_48            0.0    0.0      2.0  1.0   NaN       2.0     2.0
# stk-fl-4665_48            0.0    0.0      2.0  2.0   NaN       2.0     2.0
# stk-fl-5145_48            0.0    0.0      2.0  1.0   NaN       2.0     2.0
# stk-fl-5178_48            0.0    0.0      1.0  1.0   NaN       2.0     2.0
# stk-fl-5179_48            1.0    0.0      1.0  1.0   NaN       2.0     2.0
#
# chemical_name     exchangeable_k  iron  magnesium  manganese  organic_matter  \
# barcode_crop
# 0.P-GB_8669                  2.0   2.0        2.0        2.0             0.0
# 0CP-AE_.3448                 2.0   3.0        3.0        2.0             2.0
# 1692083006981_10             0.0   2.0        NaN        2.0             2.0
# 1693472359551_10             3.0   2.0        NaN        3.0             2.0
# 1693917106291_10             3.0   2.0        NaN        3.0             2.0
# ...                          ...   ...        ...        ...             ...
# stk-fl-4293_48               2.0   2.0        2.0        2.0             2.0
# stk-fl-4665_48               2.0   2.0        2.0        2.0             2.0
# stk-fl-5145_48               2.0   2.0        2.0        2.0             2.0
# stk-fl-5178_48               2.0   2.0        2.0        2.0             2.0
# stk-fl-5179_48               2.0   2.0        1.0        2.0             2.0
#
# chemical_name      ph  sand  silt  total_nitrogen  zinc
# barcode_crop
# 0.P-GB_8669       2.0   3.0   1.0             0.0   2.0
# 0CP-AE_.3448      2.0   3.0   3.0             1.0   1.0
# 1692083006981_10  0.0   NaN   0.0             3.0   3.0
# 1693472359551_10  1.0   NaN   0.0             2.0   3.0
# 1693917106291_10  1.0   NaN   0.0             2.0   3.0
# ...               ...   ...   ...             ...   ...
# stk-fl-4293_48    2.0   NaN   NaN             1.0   2.0
# stk-fl-4665_48    2.0   NaN   NaN             2.0   2.0
# stk-fl-5145_48    2.0   NaN   NaN             1.0   2.0
# stk-fl-5178_48    1.0   NaN   NaN             2.0   1.0
# stk-fl-5179_48    1.0   NaN   NaN             2.0   2.0
#
# [138024 rows x 17 columns]

# %%
reports_pivot_2 = reports_pivot_2.replace(3,status_dict_inv[3]).replace(2,status_dict_inv[2]).replace(1,status_dict_inv[1]).replace(0,status_dict_inv[0])

# %%
reports_pivot_2
# Out:
# chemical_name    available_p     boron  calcium       cec      clay  cn_ratio  \
# barcode_crop
# 0.P-GB_8669         very low       low  optimum  very low       low       NaN
# 0CP-AE_.3448        very low  very low  optimum       low      high   optimum
# 1692083006981_10    very low      high      NaN  very low  very low  very low
# 1693472359551_10         low      high      NaN   optimum  very low   optimum
# 1693917106291_10         low      high      NaN   optimum  very low   optimum
# ...                      ...       ...      ...       ...       ...       ...
# stk-fl-4293_48      very low  very low  optimum       low       NaN   optimum
# stk-fl-4665_48      very low  very low  optimum   optimum       NaN   optimum
# stk-fl-5145_48      very low  very low  optimum       low       NaN   optimum
# stk-fl-5178_48      very low  very low      low       low       NaN   optimum
# stk-fl-5179_48           low  very low      low       low       NaN   optimum
#
# chemical_name      copper exchangeable_k     iron magnesium manganese  \
# barcode_crop
# 0.P-GB_8669           low        optimum  optimum   optimum   optimum
# 0CP-AE_.3448      optimum        optimum     high      high   optimum
# 1692083006981_10     high       very low  optimum       NaN   optimum
# 1693472359551_10     high           high  optimum       NaN      high
# 1693917106291_10     high           high  optimum       NaN      high
# ...                   ...            ...      ...       ...       ...
# stk-fl-4293_48    optimum        optimum  optimum   optimum   optimum
# stk-fl-4665_48    optimum        optimum  optimum   optimum   optimum
# stk-fl-5145_48    optimum        optimum  optimum   optimum   optimum
# stk-fl-5178_48    optimum        optimum  optimum   optimum   optimum
# stk-fl-5179_48    optimum        optimum  optimum       low   optimum
#
# chemical_name    organic_matter        ph  sand      silt total_nitrogen  \
# barcode_crop
# 0.P-GB_8669            very low   optimum  high       low       very low
# 0CP-AE_.3448            optimum   optimum  high      high            low
# 1692083006981_10        optimum  very low   NaN  very low           high
# 1693472359551_10        optimum       low   NaN  very low        optimum
# 1693917106291_10        optimum       low   NaN  very low        optimum
# ...                         ...       ...   ...       ...            ...
# stk-fl-4293_48          optimum   optimum   NaN       NaN            low
# stk-fl-4665_48          optimum   optimum   NaN       NaN        optimum
# stk-fl-5145_48          optimum   optimum   NaN       NaN            low
# stk-fl-5178_48          optimum       low   NaN       NaN        optimum
# stk-fl-5179_48          optimum       low   NaN       NaN        optimum
#
# chemical_name        zinc
# barcode_crop
# 0.P-GB_8669       optimum
# 0CP-AE_.3448          low
# 1692083006981_10     high
# 1693472359551_10     high
# 1693917106291_10     high
# ...                   ...
# stk-fl-4293_48    optimum
# stk-fl-4665_48    optimum
# stk-fl-5145_48    optimum
# stk-fl-5178_48        low
# stk-fl-5179_48    optimum
#
# [138024 rows x 17 columns]

# %%
reports_pivot_2['crop_id'] = [str(i).split("_")[-1].strip() for i in reports_pivot_2.index]

# %%
reports_pivot_2['barcode'] = ["_".join(str(i).split("_")[:-1]).strip() for i in reports_pivot_2.index]

# %%
reports_pivot_2.to_csv("inputFiles/reports_final.csv")

# %%
reports_pivot_2 = pd.read_csv("inputFiles/reports_final.csv")
# Out:
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\2138674722.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   reports_pivot_2 = pd.read_csv("inputFiles/reports_final.csv")

# %%
spectral_sample_df = pd.DataFrame()

# %%
conn = get_db_cursor()
cur = conn.cursor()
renaming = {}
for index, row in comparison_df.iterrows():
    os.makedirs("outputFiles/opus_renamed",exist_ok=True)
    os.makedirs("outputFiles/opus",exist_ok=True)
    barcode = row['barcode']
    if len([i for i in Path('./outputFiles/opus_renamed').rglob(f"*{barcode}*")]) == 2:
        continue
    print(barcode)
    crop = row['crop']
    ph = row['ph']
    phosphorus = row['phosphorus']
    potassium = row['potassium']
    organic_matter = row['Organic Matter']
    calcium = row['calcium']
    magnesium = row['magnesium']

    crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]

    crop_reports = (reports_pivot_2.loc[reports_pivot_2['crop_id'] == str(crop_id)])
    if(ph in ['low','very low','optimum','high','very high']):
        crop_reports = crop_reports.loc[crop_reports['ph'] == ph]
    if(phosphorus in ['low','very low','optimum','high','very high']):
        crop_reports = crop_reports.loc[crop_reports['available_p'] == phosphorus]
    if(potassium in ['low','very low','optimum','high','very high']):
        crop_reports = crop_reports.loc[crop_reports['exchangeable_k'] == potassium]
    if(calcium in ['low','very low','optimum','high','very high']):
        crop_reports = crop_reports.loc[crop_reports['calcium'] == calcium]
    if(magnesium in ['low','very low','optimum','high','very high']):
        crop_reports = crop_reports.loc[crop_reports['magnesium'] == magnesium]
    if(len(crop_reports) == 0):
        continue
    spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
    spectral_df = spectral_df.loc[spectral_df['spectral_batch_id'] > 3355]
    
    folder = f"./outputFiles/{crop}_ph-{ph}_phosphorus-{phosphorus}_potassium-{potassium}_organicmatter-{organic_matter}_calcium-{calcium}_magnesium-{magnesium}"
    os.makedirs(folder, exist_ok=True)
    print(f"======================{folder}======================")
    for index, row in spectral_df.iterrows():
        batch_no = row['spectral_batch_id']
        print(f"Downloading batch no {batch_no}")
        if len([i for i in Path('./outputFiles/opus_renamed').rglob(f"*{barcode}*")]) == 2:
            break
        try:
            subprocess.run(f"scp -r root@161.35.160.152:/mnt/volume_lon1_01/spc_backup/batch_{batch_no} {folder}")
            
            count = 0
            for file in [i for i in Path(folder).rglob("**/*.0")][::-1]:
                if(count==2):
                    break
                directory = file.parent
                name = file.name
                actual_barcode = name.split("_")[0]
                
                shutil.copyfile(file,f"outputFiles/opus/{name}")
                os.rename(file,f"outputFiles/opus_renamed/{barcode}_{count}.0")
                renaming[actual_barcode] = barcode
                row['barcode'] = barcode
                row['Report Language'] = 'en'
                spectral_sample_df = pd.concat([spectral_sample_df, row])
                
                count+=1
            
        except Exception as e:
            print(e)

subprocess.run(f"powershell Compress-Archive {os.getcwd()}\\outputFiles\\opus_renamed {os.getcwd()}\\outputFiles\\opus.zip")
# Out:
# TEST-DS1-0001
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#      spectral_sample_id        barcode  spectral_batch_id   latitude  \
# 0                 62701   FWM-ML-00296               2125 -16.288246
# 1                 63135   FWM-ML-01242               2165 -15.153721
# 2                 63354   FWM-ML-00242               2059 -15.555316
# 3                 63823   FWM-ML-01974               2129 -16.458097
# 4                 64748   FWM-ML-01287               2164 -15.106010
# ..                  ...            ...                ...        ...
# 977              227409  OCP-GH-AGB645               7978  10.703134
# 978              228667   DS-FL19-0015               8107   0.862370
# 979              230906   OCP-GH-BR817               7860   7.573072
# 980              231339   FTMA-FL-8360               8213   0.043945
# 981              231345   FTMA-FL-8364               8213   0.043945
#
#      longitude                                        farmer_name  \
# 0    34.842118                                    Lucy chimbadza
# 1    34.999861                                      Yudasi lucius
# 2    34.698274                                        Dalia daudi
# 3    34.906922                                    Emanuel Bishika
# 4    35.093272                                  Bauleni mtapasha
# ..         ...                                                ...
# 977  -1.278120                                     Clement Asonka
# 978  34.928005                                           Farmer 5
# 979  -2.705770                                  Fortunately Derly
# 980  37.645568  Cereal Growers  Association (Ntumburi Demonsit...
# 981  37.645568  Cereal Growers  Association (Rwarera AEP Demo ...
#
#                 sampler_name  previous_crop next_crop         sample_date  \
# 0                     Nchalo          Maize     Maize 2019-07-31 11:40:25
# 1                     Nkaya2          Maize     Maize 2019-07-31 10:58:49
# 2                   Chifunga          Maize     Maize 2019-07-30 13:47:51
# 3                      Ngabu          Maize     Maize 2019-08-05 07:34:52
# 4                   Kwitanda          Maize     Maize 2019-08-01 09:27:05
# ..                       ...            ...       ...                 ...
# 977         Georgina Awaatey          Maize     Maize 2023-09-06 09:36:12
# 978                      ttu          maize     maize 2023-03-13 00:00:00
# 979           Adjei Emmanuel          Maize     Maize 2023-09-20 07:29:21
# 980  Nicholas Mutetha Nkanda          Wheat     Maize 2023-09-21 10:52:52
# 981  Nicholas Mutetha Nkanda  Beans (Nyayo)     Maize 2023-09-21 11:06:11
#
#     phone_number            analysis_type tree_population   age  field_size
# 0     0991807486         Soil Test Report            None  None         NaN
# 1     0882610971         Soil Test Report            None  None         NaN
# 2     0881975405         Soil Test Report            None  None         NaN
# 3     0992346666         Soil Test Report            None  None         NaN
# 4     0997373075         Soil Test Report            None  None         NaN
# ..           ...                      ...             ...   ...         ...
# 977   0241527112         Soil Test Report            None  None         1.0
# 978    715341345        Soil Starter Scan            None  None         NaN
# 979   0530333019         Soil Test Report            None  None         1.0
# 980    721783976  Starter Soil Scan (MIR)            None  None         0.5
# 981    721783976  Starter Soil Scan (MIR)            None  None         0.6
#
# [982 rows x 15 columns]
# ======================./outputFiles/Maize_ph-high_phosphorus-high_potassium-high_organicmatter-nan_calcium-nan_magnesium-nan======================
# Downloading batch no 2125
# Downloading batch no 2165
# Downloading batch no 2059
# Downloading batch no 2129
# Downloading batch no 2164
# Downloading batch no 2127
# Downloading batch no 2129
# Downloading batch no 2258
# Downloading batch no 3970
# Downloading batch no 5512
# TEST-DS1-0002
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#     spectral_sample_id       barcode  spectral_batch_id   latitude  longitude  \
# 0                62324  FWM-ML-00107               2078 -15.701513  35.679930
# 1                64118  FWM-ML-00255               2068 -15.004615  35.506518
# 2                65325  FWM-ML-00629               2052 -14.787851  34.620889
# 3                70700  FWM-ML-00652               2150 -14.595053  35.534599
# 4                63274  FWM-ML-00699               2028 -14.973633  35.599644
# 5                63270  FWM-ML-00898               2028 -14.977474  35.586703
# 6                62487  FWM-ML-01064               2020 -15.043040  35.385472
# 7                63282  FWM-ML-01081               2028 -14.972389  35.604954
# 8                63318  FWM-ML-01410               2028 -14.969727  35.649629
# 9                67168  FWM-ML-01674               2077 -15.680912  35.309003
# 10               64051  FWM-ML-01719               2099 -16.014327  35.294225
# 11               70362  FWM-ML-01747               2173 -15.942006  35.100694
# 12               65275  FWM-ML-01778               2104 -15.589063  35.166993
# 13               64106  FWM-ML-01781               2118 -15.484329  35.219433
# 14               68488  FWM-ML-01788               2138 -14.312284  35.559562
# 15               66964  FWM-ML-01873               2077 -15.677497  35.308738
# 16               70343  FWM-ML-02151               2223 -14.207466  33.777050
# 17               69148  FWM-ML-02171               2223 -14.201829  33.776736
# 18               68199  FWM-ML-02184               2265 -13.892947  33.491862
# 19               68233  FWM-ML-02273               2265 -13.893244  33.498879
# 20               69071  FWM-ML-02298               2199 -14.032314  33.473669
# 21              192981  FWM-ML-32709               6338 -13.975737  33.286332
# 22              227827  FWM-ML-33155               8190 -13.773121  34.602339
# 23              227825  FWM-ML-33169               8190 -13.773248  34.602456
# 24              227824  FWM-ML-33170               8190 -13.772875  34.602340
# 25              190251  FWM-ML-33306               6326 -13.895951  33.489413
# 26              179928  FWM-ML-34455               6472 -13.817345  33.008013
# 27              192367  FWM-ML-36204               6592 -15.937502  35.179819
# 28              193082  FWM-ML-41917               6395 -12.147210  33.454803
# 29              191874  FWM-ML-41948               6394 -12.147244  33.455149
# 30              190154  FWM-ML-41985               6395 -12.142285  33.460158
# 31              211512  FWM-ML-44239               7222 -13.899659  33.799711
# 13 2019-08-06 10:09:55    0883686940   Soil Test Report            None  None
# 14 2019-08-21 10:23:54    0882457218   Soil Test Report            None  None
# 15 2019-08-15 11:10:59    0995806237   Soil Test Report            None  None
# 16 2019-08-28 07:24:57    0884645208   Soil Test Report            None  None
# 17 2019-08-24 08:07:55    0884645208   Soil Test Report            None  None
# 18 2019-08-20 17:21:45    0991984263   Soil Test Report            None  None
# 19 2019-08-20 17:25:14    0991984263   Soil Test Report            None  None
# 20 2019-08-23 13:12:59    0993706698   Soil Test Report            None  None
# 21 2022-11-16 12:59:21     991833404   Soil Test Report            None  None
# 22 2023-09-12 07:08:00    0888413833   Soil Test Report            None  None
# 23 2023-09-12 07:15:08    0888413833   Soil Test Report            None  None
# 24 2023-09-12 07:19:23    0888413833   Soil Test Report            None  None
# 25 2022-11-09 05:59:26     998559319   Soil Test Report            None  None
# 26 2022-09-05 06:31:51    0997217413   Soil Test Report            None  None
# 27 2022-11-15 11:47:02    0995669458   Soil Test Report            None  None
# 28 2022-11-17 05:11:56    0992119046   Soil Test Report            None  None
# 29 2022-11-14 15:52:45    0884241884   Soil Test Report            None  None
# 30 2022-11-08 14:31:16    0999437814   Soil Test Report            None  None
# 31 2023-05-02 06:54:29    0888124693   Soil Test Report            None  None
# 32 2023-01-16 12:57:22  255758582893  Soil Starter Scan            None  None
#
#     field_size
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         1.0
# 22         1.0
# 23         1.0
# 24         1.0
# 25         1.0
# 26         1.0
# 27         1.0
# 28         1.0
# 29         1.0
# 30         1.0
# 31         1.0
# 32         NaN
# ======================./outputFiles/Maize_ph-low_phosphorus-high_potassium-low_organicmatter-optimum_calcium-nan_magnesium-nan======================
# Downloading batch no 2078
# Downloading batch no 2068
# Downloading batch no 2052
# Downloading batch no 2150
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2020
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2077
# Downloading batch no 2099
# Downloading batch no 2173
# Downloading batch no 2104
# Downloading batch no 2118
# Downloading batch no 2138
# Downloading batch no 2077
# Downloading batch no 2223
# Downloading batch no 2223
# Downloading batch no 2265
# Downloading batch no 2265
# Downloading batch no 2199
# Downloading batch no 6338
# Downloading batch no 8190
# TEST-DS1-0003
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#      spectral_sample_id        barcode  spectral_batch_id   latitude  \
# 0                 54800    OCP-GH-7321               1587  11.033753
# 1                 61758   FWM-ML-01454               2009 -14.979851
# 2                 61961   FWM-ML-00376               2130 -14.907482
# 3                 62010   FWM-ML-00357               2073 -15.454322
# 4                 63294   FWM-ML-00501               2065 -15.002168
# ..                  ...            ...                ...        ...
# 657              195629   OCP-GH-VR823               6434   7.044574
# 658              199071    OAF-TZ-0014               6682  -9.169246
# 659              199981   FTMA-FL-8719               6781   0.571963
# 660              200237  OCP-GH-VR1570               6799   6.849829
# 661              203231  OCP-GH-VR3935               6872   6.773384
#
#      longitude                                        farmer_name  \
# 0    -0.206490                                    Abdullah  Awini
# 1    35.571631                                     Chiwalo bamusi
# 2    35.531744                                        Ester John
# 3    35.238969                                      Philles mdala
# 4    35.516267                                     Anganire White
# ..         ...                                                ...
# 657   0.557059                                 Homatekpo pheobian
# 658  34.747643                                       Aizack Mhuhi
# 659  34.562143  Sheilla N Masinde (Sheila Masinde Farm Muungan...
# 660   0.417084                                     Bernard Abotsi
# 661   0.518546                                         Tefe Doris
#
#           sampler_name previous_crop next_crop         sample_date  \
# 0          Bukari Fati         Maize     Maize 2019-05-15 05:55:16
# 1         Saidi School         Maize     Maize 2019-07-29 14:52:36
# 2                Ntaja         Maize     Maize 2019-07-30 08:55:26
# 3              Thondwe         Maize     Maize 2019-07-30 10:37:46
# 4         Saidi School         Maize     Maize 2019-08-03 09:13:40
# ..                 ...           ...       ...                 ...
# 657      Adabra Joseph         Maize     Maize 2022-12-09 05:59:56
# 658  OAF_Beverly Agesa         Maize     Maize 2023-01-16 12:57:22
# 659         John Njogo         Maize     Maize 2023-01-30 15:41:04
# 660      Agozi Forster         Maize     Maize 2023-02-01 07:22:45
# 661      Akuako Israel         Maize     Maize 2023-02-16 14:27:22
#
#      phone_number            analysis_type tree_population   age  field_size
# 0      0243866161         Soil Test Report            None  None         NaN
# 1      0995309476         Soil Test Report            None  None         NaN
# 2      0992545117         Soil Test Report            None  None         NaN
# 3      0888003432         Soil Test Report            None  None         NaN
# 4      0888355628         Soil Test Report            None  None         NaN
# ..            ...                      ...             ...   ...         ...
# 657    0543848692         Soil Test Report            None  None         1.0
# 658  255758582893        Soil Starter Scan            None  None         NaN
# 659     726936244  Starter Soil Scan (MIR)            None  None         9.0
# 660    0550547969         Soil Test Report            None  None         1.0
# 661    0545749067         Soil Test Report            None  None         1.0
#
# [662 rows x 15 columns]
# ======================./outputFiles/maize_ph-low_phosphorus-low_potassium-low_organicmatter-optimum_calcium-nan_magnesium-nan======================
# Downloading batch no 1587
# Downloading batch no 2009
# Downloading batch no 2130
# Downloading batch no 2073
# Downloading batch no 2065
# Downloading batch no 2132
# Downloading batch no 2155
# Downloading batch no 2154
# Downloading batch no 2132
# Downloading batch no 3296
# Downloading batch no 3384
# Downloading batch no 3361
# TEST-DS1-0004
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#      spectral_sample_id       barcode  spectral_batch_id  latitude  longitude  \
# 0                171241  OCP-T1-10600               5602 -6.797340  32.020260
# 1                171918  OCP-T1-10594               5604 -6.814499  32.090313
# 2                174718  OCP-T1-11929               5834 -3.241784  30.935102
# 3                175307  OCP-T2-11952               5503 -6.087965  31.171287
# 4                175326  OCP-T2-11992               5504 -6.064693  31.135415
# ..                  ...           ...                ...       ...        ...
# 204              228323  OCP-T1-22594               8210 -1.545708  31.426348
# 205              229453  OCP-T1-22450               8211 -2.261591  31.511415
# 206              229468  OCP-T1-22465               8211 -2.269508  31.505404
# 207              230135  OCP-T1-21932               8209 -1.581335  31.428810
# 208              233536  OCP-T1-22111               8209 -1.556318  31.461151
#
#                   farmer_name    sampler_name previous_crop next_crop  \
# 0    FABIANO FUTAKAMBA NKUNDA   Samiu Yussuph         Maize     Beans
# 1     ELIZABETI KASHINJE SEKA   Samiu Yussuph          Rice     Beans
# 2                Jackson Juma    Kweli Lazaro         Maize     Beans
# 3               Eduadi petrol   Fagason Maeda         Maize     Beans
# 4                Mussa yohana   Fagason Maeda         Maize     Beans
# ..                        ...             ...           ...       ...
# 204   Anatory Rwehumbiza Alex  Festus Katemba         Maize     Beans
# 205         Vicencia Theobard   Judih Buberwa        Fallow     Beans
# 206             Doricas Ayubu   Judih Buberwa         Maize     Beans
# 207  Geofrey Herman Nkonjelwa  Festus Katemba         Maize     Beans
# 208      Dauda Husein Taslima  Festus Katemba         Maize     Beans
#
#             sample_date phone_number     analysis_type tree_population   age  \
# 0   2022-07-12 12:23:11   0627498477  Soil Test Report            None  None
# 1   2022-07-15 06:24:11   0747403653  Soil Test Report            None  None
# 2   2022-07-25 13:26:16   0716994022  Soil Test Report            None  None
# 3   2022-07-27 06:30:18   0758303185  Soil Test Report            None  None
# 4   2022-07-27 06:35:40   0622013277  Soil Test Report            None  None
# ..                  ...          ...               ...             ...   ...
# 204 2023-09-13 15:45:02   0769278674  Soil Test Report            None  None
# 205 2023-09-16 09:05:19   0763971966  Soil Test Report            None  None
# 206 2023-09-16 09:12:41   0758265660  Soil Test Report            None  None
# 207 2023-09-18 14:01:32   0744413546  Soil Test Report            None  None
# 208 2023-09-28 14:33:40   0764233385  Soil Test Report            None  None
#
#      field_size
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ..          ...
# 204         1.0
# 205         1.0
# 206         1.0
# 207         1.0
# 208         1.0
#
# [209 rows x 15 columns]
# ======================./outputFiles/Beans_ph-high_phosphorus-high_potassium-high_organicmatter-low_calcium-nan_magnesium-nan======================
# Downloading batch no 5602
# Downloading batch no 5604
# TEST-DS1-0005
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# TEST-DS1-0006
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#     spectral_sample_id       barcode  spectral_batch_id   latitude  longitude  \
# 0               175953  FtMA-FL-1283               5557   0.335837  34.531549
# 1               184297  FTMA-FL-2136               6071   0.279377  34.739739
# 2               193009  FTMA-FL-9514               6273   0.604453  34.544704
# 3               210480  FWM-ML-44093               7168 -13.899895  33.799831
# 4               192736   MAR-FL-0006               6222  -1.126135  36.641885
# 5               173922  OCP-T1-11789               5836  -3.429790  30.723637
# 6               173944  OCP-T1-11983               5836  -3.577343  30.731223
# 7               174039  OCP-T1-11989               5844  -3.359879  30.838002
# 8               228084  OCP-T1-21805               8198  -1.337043  31.736880
# 9               231186  OCP-T1-22634               8196  -1.377242  31.757075
# 10              231379  OCP-T1-22772               8199  -1.545637  31.588193
# 11              172151  OCP-T2-11640               5627  -6.255866  30.726219
# 12              176040  OCP-T2-12204               5624  -5.800409  30.597584
# 13              175530  OCP-T2-12295               5624  -5.800409  30.597584
# 14              214939   PAG-FL-2156               7453   1.162800  34.998400
# 15              214940   PAG-FL-2170               7451   0.942140  34.821200
# 16              214870   PAG-FL-2197               7451   0.978300  35.220200
# 17              207096   SMS-FL-2315               7182   0.830238  34.789441
#
#                                           farmer_name          sampler_name  \
# 0       Alex Livgstone Ongwen (Alex Farm - Field Two)        Norbbert Okutu
# 1         Frederick Chimwani (Fred Farm - Fred  Farm)         Rapando Monca
# 2          Peter Muturi (Peter Muturi - Peter Muturi)            John Njogo
# 3                     Pakati pansi, pafupi ndi ground          Olive Masaka
# 4               Wilfred Andai (Wilfred Andai - Mitua)          Paris Agviza
# 5                                     MAJARIWA RUTIKA          Kweli Lazaro
# 6                                    JEMSI RULELEKANA          Kweli Lazaro
# 7                                    DAMASI MALIKIOLO          Kweli Lazaro
# 8                                    Jovitus Josephat       Consolatha Temu
# 9                                  Thopister Mwombeki       Consolatha Temu
# 10                           RENATHA SEVERIN KASHASHA         Samuel Kapufi
# 11                                Christopher  Joseph  Emmanuel Kulangesiwa
# 12                                        Yoyi zabron            Musa Mkisi
# 13                                       Amani jailos            Musa Mkisi
# 14                           Andrew Kipsang Chepkwony        Vincent Mkamba
# 15                                    Bravin Wanyonyi        Vincent Mkamba
# 16                            Annah Chepkoskei Chebii        Amos Toroitich
# 17  SMS CFIR Kamusinde FC's (Fransis Matere Mno.20...        Mulanda Dorice
#
#      previous_crop next_crop         sample_date  phone_number  \
# 0            Maize     Beans 2022-07-30 12:18:13     720230509
# 1            Maize     Beans 2022-10-12 21:26:52     718807776
# 2            Maize     Maize 2022-11-16 17:47:45     702186197
# 3           Fallow     Beans 2023-04-12 06:41:12    0994111319
# 4            Maize     Beans 2022-11-16 11:04:53     723742248
# 5            Maize     Beans 2022-07-22 13:19:17    0756011898
# 6            Maize     Beans 2022-07-22 14:44:22    0756011898
# 7        Sunflower     Beans 2022-07-23 09:11:04    0624647337
# 8            Maize     Beans 2023-09-13 07:22:16    0754953479
# 9            Maize     Beans 2023-09-20 08:39:17    0759222870
# 10           Maize     Beans 2023-09-21 14:11:47    0764331718
# 11           Maize     Beans 2022-07-16 06:53:11    0620852306
# 12  Irish Potatoes     Beans 2022-07-28 10:12:31    0686749486
# 13           Maize     Beans 2022-07-28 10:14:27    0629526007
# 14           Beans     Beans 2023-06-27 00:00:00  254724224006
# 15           Beans     Beans 2023-06-27 00:00:00  254748180061
# 16           Beans     Beans 2023-06-27 00:00:00     710411602
# 17          Coffee    Coffee 2023-03-22 13:08:05     743200015
#
#               analysis_type tree_population   age  field_size
# 0    Starter Soil Scan (IR)            None  None         1.0
# 1    Starter Soil Scan (IR)            None  None         1.0
# 2    Starter Soil Scan (IR)            None  None        15.0
# 3          Soil Test Report            None  None         1.0
# 4    Starter Soil Scan (IR)            None  None         1.0
# 5          Soil Test Report            None  None         1.0
# 6          Soil Test Report            None  None         1.0
# 7          Soil Test Report            None  None         1.0
# 8          Soil Test Report            None  None         1.0
# 9          Soil Test Report            None  None         1.0
# 10         Soil Test Report            None  None         1.0
# 11         Soil Test Report            None  None         1.0
# 12         Soil Test Report            None  None         1.0
# 13         Soil Test Report            None  None         1.0
# 14        Soil Starter Scan            None  None         NaN
# 15        Soil Starter Scan            None  None         NaN
# 16        Soil Starter Scan            None  None         NaN
# 17  Starter Soil Scan (MIR)            None  None         1.0
# ======================./outputFiles/Beans_ph-low_phosphorus-low_potassium-low_organicmatter-low_calcium-nan_magnesium-nan======================
# Downloading batch no 5557
# Downloading batch no 6071
# TEST-DS1-0007
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crop_id = pd.read_sql(f"SELECT id FROM crop c WHERE c.name = '{crop}'", con=conn).id.values[0]
# C:\Users\tommy\AppData\Local\Temp\ipykernel_14088\747565599.py:34: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   spectral_df = pd.read_sql(f"SELECT spectral_sample_id, barcode, spectral_batch_id, latitude, longitude, farmer_name, sampler_name, previous_crop, next_crop, sample_date, phone_number, analysis_type, tree_population,  TIMESTAMPDIFF(YEAR,'2024-17-05',date_of_planting) as 'age', field_size  FROM SpectralSample WHERE barcode IN {tuple(crop_reports['barcode'].values)}", con=conn)
#       spectral_sample_id        barcode  spectral_batch_id   latitude  \
# 0                  54800    OCP-GH-7321               1587  11.033753
# 1                  54802    OCP-GH-7323               1587  11.026956
# 2                  55198    OCP-GH-7742               1585  11.026267
# 3                  61751   FWM-ML-00323               2078 -15.725736
# 4                  61753   FWM-ML-02028               2130 -14.886965
# ...                  ...            ...                ...        ...
# 3158              225693  OCP-GH-BRR103               7883   8.023784
# 3159              227132   OCP-GH-BRR77               7848   7.684589
# 3160              227354  OCP-GH-BRR208               7847   7.747310
# 3161              230735   OCP-GH-BR294               7859   7.742996
# 3162              230868   OCP-GH-BR577               7860   7.574276
#
#       longitude                farmer_name    sampler_name previous_crop  \
# 0     -0.206490            Abdullah  Awini     Bukari Fati         Maize
# 1     -0.209229   Yakubu Alhassan  Zangina     Bukari Fati         Maize
# 2     -0.261377              Ibrahim Maria  Akugri m Naomi         Maize
# 3     35.692864             Zione chilewan          Migowi         Maize
# 4     35.558438              Esnart James            Ntaja         Maize
# ...         ...                        ...             ...           ...
# 3158  -2.535580              Mensah  mates      North East         Maize
# 3159  -2.627284  Akyembota Akosua Akabange   Forster Adjei         Maize
# 3160  -2.606819                Teinuo Tang   Forster Adjei         Maize
# 3161  -2.737086                 KUMI EVANS    Daare Thomas         Maize
# 3162  -2.695845              Opera  Ameyaa  Adjei Emmanuel         Maize
#
#      next_crop         sample_date phone_number     analysis_type  \
# 0        Maize 2019-05-15 05:55:16   0243866161  Soil Test Report
# 1        Maize 2019-05-15 05:57:03   0243201514  Soil Test Report
# 2        Maize 2019-05-18 13:43:34   0556876065  Soil Test Report
# 3        Maize 2019-07-29 16:24:42   0886881588  Soil Test Report
# 4        Maize 2019-07-29 16:21:38   0992573761  Soil Test Report
# ...        ...                 ...          ...               ...
# 3158     Maize 2023-08-26 08:55:09   0542094274  Soil Test Report
# 3159     Maize 2023-09-03 13:48:10   0596164697  Soil Test Report
# 3160     Maize 2023-09-05 06:57:49   0595390605  Soil Test Report
# 3161     Maize 2023-09-19 06:56:19   0245100206  Soil Test Report
# 3162     Maize 2023-09-20 09:49:07   0241056507  Soil Test Report
#
#      tree_population   age  field_size
# 0               None  None         NaN
# 1               None  None         NaN
# 2               None  None         NaN
# 3               None  None         NaN
# 4               None  None         NaN
# ...              ...   ...         ...
# 3158            None  None         1.0
# 3159            None  None         1.0
# 3160            None  None         1.0
# 3161            None  None         1.0
# 3162            None  None         1.0
#
# [3163 rows x 15 columns]
# ======================./outputFiles/Maize_ph-low_phosphorus-nan_potassium-nan_organicmatter-nan_calcium-low_magnesium-optimum======================
# Downloading batch no 1587
# Downloading batch no 1587
# Downloading batch no 1585
# Downloading batch no 2078
# Downloading batch no 2130
# Downloading batch no 2009
# Downloading batch no 2009
# Downloading batch no 2009
# Downloading batch no 2009
# Downloading batch no 2130
# Downloading batch no 2129
# Downloading batch no 2073
# Downloading batch no 2149
# Downloading batch no 2177
# Downloading batch no 2009
# Downloading batch no 2078
# Downloading batch no 2009
# Downloading batch no 2020
# Downloading batch no 2111
# Downloading batch no 2111
# Downloading batch no 2080
# Downloading batch no 2065
# Downloading batch no 2070
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2028
# Downloading batch no 2126
# Downloading batch no 2099
# Downloading batch no 2100
# Downloading batch no 2174
# Downloading batch no 2104
# Downloading batch no 2179
# Downloading batch no 2065
# Downloading batch no 2099
# Downloading batch no 2100
# Downloading batch no 2118
# Downloading batch no 2118
# Downloading batch no 2068
# Downloading batch no 2080
# Downloading batch no 2080
# Downloading batch no 2078
# Downloading batch no 2132
# Downloading batch no 2155
# Downloading batch no 2155
# Downloading batch no 2154
# Downloading batch no 2070
# Downloading batch no 2154
# Downloading batch no 2054
# Downloading batch no 2054
# Downloading batch no 2125
# Downloading batch no 2125
# Downloading batch no 2100
# Downloading batch no 2100
# Downloading batch no 2137
# Downloading batch no 2137
# Downloading batch no 2149
# Downloading batch no 2104
# Downloading batch no 2052
# Downloading batch no 2052
# Downloading batch no 2052
# Downloading batch no 2168
# Downloading batch no 2068
# Downloading batch no 2096
# Downloading batch no 2096
# Downloading batch no 2096
# Downloading batch no 2096
# Downloading batch no 2096
# Downloading batch no 2096
# Downloading batch no 2068
# Downloading batch no 2132
# Downloading batch no 2103
# Downloading batch no 2077
# Downloading batch no 2126
# Downloading batch no 2126
# Downloading batch no 2126
# Downloading batch no 2065
# Downloading batch no 2129
# Downloading batch no 2077
# Downloading batch no 2077
# Downloading batch no 2224
# Downloading batch no 2138
# Downloading batch no 2138
# Downloading batch no 2224
# Downloading batch no 2151
# Downloading batch no 2151
# Downloading batch no 2151
# Downloading batch no 2151
# Downloading batch no 2151
# Downloading batch no 2201
# Downloading batch no 2265
# Downloading batch no 2265
# Downloading batch no 2235
# Downloading batch no 2236
# Downloading batch no 2236
# Downloading batch no 2235
# Downloading batch no 2235
# Downloading batch no 2150
# Downloading batch no 2199
# Downloading batch no 2199
# Downloading batch no 2223
# Downloading batch no 2223
# Downloading batch no 2223
# Downloading batch no 2223
# Downloading batch no 2200
# Downloading batch no 2246
# Downloading batch no 2173
# Downloading batch no 2173
# Downloading batch no 2173
# Downloading batch no 2182
# Downloading batch no 2182
# Downloading batch no 2221
# Downloading batch no 2221
# Downloading batch no 2221
# Downloading batch no 3238
# Downloading batch no 3145
# Downloading batch no 3177
# Downloading batch no 3178
# Downloading batch no 3178
# Downloading batch no 3177
# Downloading batch no 3207
# Downloading batch no 3159
# Downloading batch no 3159
# Downloading batch no 3160
# Downloading batch no 3178
# Downloading batch no 3184
# Downloading batch no 3192
# Downloading batch no 3190
# Downloading batch no 3178
# Downloading batch no 3168
# Downloading batch no 3163
# Downloading batch no 3161
# Downloading batch no 3163
# Downloading batch no 3177
# Downloading batch no 3184
# Downloading batch no 3182
# Downloading batch no 3178
# Downloading batch no 3177
# Downloading batch no 3164
# Downloading batch no 3164
# Downloading batch no 3191
# Downloading batch no 3185
# Downloading batch no 3185
# Downloading batch no 3186
# Downloading batch no 3193
# Downloading batch no 3215
# Downloading batch no 3179
# Downloading batch no 3193
# Downloading batch no 3161
# Downloading batch no 3193
# Downloading batch no 3207
# Downloading batch no 3178
# Downloading batch no 3191
# Downloading batch no 3193
# Downloading batch no 3193
# Downloading batch no 3195
# Downloading batch no 3193
# Downloading batch no 3178
# Downloading batch no 3191
# Downloading batch no 3181
# Downloading batch no 3178
# Downloading batch no 3178
# Downloading batch no 3195
# Downloading batch no 3195
# Downloading batch no 3195
# Downloading batch no 3193
# Downloading batch no 3195
# Downloading batch no 3180
# Downloading batch no 3167
# Downloading batch no 3198
# Downloading batch no 3177
# Downloading batch no 3197
# Downloading batch no 3196
# Downloading batch no 3234
# Downloading batch no 3198
# Downloading batch no 3198
# Downloading batch no 3198
# Downloading batch no 3198
# Downloading batch no 3206
# Downloading batch no 3206
# Downloading batch no 3206
# Downloading batch no 3204
# Downloading batch no 3204
# Downloading batch no 3204
# Downloading batch no 3204
# Downloading batch no 3198
# Downloading batch no 3206
# Downloading batch no 3184
# Downloading batch no 3204
# Downloading batch no 3198
# Downloading batch no 3206
# Downloading batch no 3206
# Downloading batch no 3185
# Downloading batch no 3185
# Downloading batch no 3192
# Downloading batch no 3185
# Downloading batch no 3185
# Downloading batch no 3185
# Downloading batch no 3185
# Downloading batch no 3196
# Downloading batch no 3206
# Downloading batch no 3234
# Downloading batch no 3172
# Downloading batch no 3193
# Downloading batch no 3193
# Downloading batch no 3195
# Downloading batch no 3195
# Downloading batch no 3180
# Downloading batch no 3179
# Downloading batch no 3195
# Downloading batch no 3192
# Downloading batch no 3192
# Downloading batch no 3192
# Downloading batch no 3181
# Downloading batch no 3192
# Downloading batch no 3192
# Downloading batch no 3181
# Downloading batch no 3207
# Downloading batch no 3197
# Downloading batch no 3196
# Downloading batch no 3197
# Downloading batch no 3196
# Downloading batch no 3196
# Downloading batch no 3196
# Downloading batch no 3207
# Downloading batch no 3209
# Downloading batch no 3208
# Downloading batch no 3218
# Downloading batch no 3203
# Downloading batch no 3229
# Downloading batch no 3212
# Downloading batch no 3212
# Downloading batch no 3269
# Downloading batch no 3207
# Downloading batch no 3203
# Downloading batch no 3211
# Downloading batch no 3212
# Downloading batch no 3212
# Downloading batch no 3211
# Downloading batch no 3211
# Downloading batch no 3220
# Downloading batch no 3211
# Downloading batch no 3212
# Downloading batch no 3212
# Downloading batch no 3211
# Downloading batch no 3212
# Downloading batch no 3217
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3219
# Downloading batch no 3236

# %%
spectral_sample_df

# %%
spectral_sample_df.to_csv("outputFiles/Spectral Sample Output.csv")
